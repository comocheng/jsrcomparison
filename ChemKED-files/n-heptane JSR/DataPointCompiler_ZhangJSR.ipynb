# %%
import numpy
import pandas as pd

# %%
file = 'n-heptane_zhang_JSR.xlsx'

# %%
quarterphi = pd.read_excel(file, sheet_name='0.25Phi')

# %%
# Out:
#     Temperature    nC7H16        O2        CO       CO2       methane  \
# 0           500  0.004906  0.233085  0.000000  0.000000  0.000000e+00
# 1           525  0.004773  0.229530  0.000000  0.000000  0.000000e+00
# 2           550  0.003780  0.229083  0.000095  0.000000  0.000000e+00
# 3           575  0.003242  0.219728  0.001025  0.000695  0.000000e+00
# 4           600  0.002342  0.214652  0.003514  0.001668  0.000000e+00
# 5           625  0.002015  0.205727  0.006173  0.002214  1.266199e-07
# 6           650  0.001794  0.210163  0.007050  0.002023  9.764400e-08
# 7           675  0.001653  0.213396  0.006516  0.001387  0.000000e+00
# 8           700  0.001635  0.213660  0.003677  0.000937  0.000000e+00
# 9           725  0.001938  0.218158  0.002841  0.000632  2.462256e-07
# 10          750  0.002021  0.213771  0.002945  0.000907  4.717751e-07
# 11          775  0.001794  0.211852  0.003648  0.001153  1.128122e-06
# ...
